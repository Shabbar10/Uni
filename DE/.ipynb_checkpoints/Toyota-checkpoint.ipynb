# %% [markdown]
# # Data Preprocessing on Toyota Dataset
# 1. Binning
# 2. Smoothening
# 3. Encoding
# 4. Scaling
# 5. Outlier analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('Toyota.csv')
df.head()
# Out:
#    Unnamed: 0  Price   Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel  90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel  90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel  90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel  90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel  90       0.0          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 123.5+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age           100
# KM              0
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    1436
# Name: count, dtype: int64

# %%
df["Doors"].unique()
# Out:
# array(['three', '3', '5', '4', 'four', 'five', '2'], dtype=object)

# %% [markdown]
# Doors column has inconsistent data. We need to make it consistent by mapping it to correct values : array(['three', '3', '5', '4', 'four', 'five', '2'], dtype=object)

# %%
df["Doors"] = df["Doors"].map({'three' : 3, 'four' : 4, 'five' : 5, '3' : 3, '2' : 2, '1' : 1, '0' : 0, '5' : 5, '4' : 4})

# %%
df.sample(frac=1).head()
# Out:
#       Unnamed: 0  Price   Age      KM FuelType   HP  MetColor  Automatic  \
# 1283        1283   8950  76.0   73116   Petrol  110       1.0          0
# 1112        1112   7750  78.0  120000   Petrol  110       0.0          0
# 434          434  10750  49.0   80090   Petrol   97       1.0          0
# 105          105  16950   NaN   13748   Petrol   97       1.0          0
# 112          112  24950   8.0      ??   Diesel  116       1.0          0
#
#         CC  Doors  Weight
# 1283  1600      5    1075
# 1112  1600      5    1075
# 434   1400      3    1030
# 105   1400      3    1100
# 112   2000      5    1320

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   int64
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 123.5+ KB

# %%
df.drop('Unnamed: 0', axis = 1, inplace=True)
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df.sample(frac=1).head(20)
# Out:
#       Price        Age      KM FuelType   HP  MetColor  Automatic    CC  \
# 351    9950  42.000000   27141   Petrol   97       1.0          0  1400
# 250   11750  33.000000   55350   Petrol  110       0.0          0  1600
# 1267   8500  73.000000   75000   Petrol  110       0.0          0  1600
# 838    9950  59.000000   67010      NaN  110       1.0          0  1600
# 1005   9750  55.672156   37759   Petrol  110       1.0          0  1600
# 294   13950  42.000000   42560   Petrol  110       1.0          0  1600
# 789    8950  62.000000   75000   Petrol  110       1.0          0  1600
# 814    8950  60.000000   70954   Petrol  110       0.0          0  1600
# 418    8950  55.000000   94401   Diesel   72       0.0          0  2000
# 307   13500  42.000000   38932   Petrol  110       1.0          0  1600
# 1081   9500  80.000000  137178   Diesel   90       1.0          0  2000
# 954    8900  61.000000   52112   Petrol  110       1.0          0  1600
# 1415   6950  72.000000   42000   Petrol  110       NaN          0  1600
# 1193   8450  70.000000   89983   Petrol  110       0.0          0  1600
# 623    8750  61.000000  136956   Petrol  110       0.0          0  1600
# 1274   9000  80.000000   74196   Petrol  110       NaN          0  1600
# 414   10900  49.000000   97600   Petrol  110       1.0          0  1600
# 150   17200  20.000000   17300   Petrol   97       1.0          0  1400
# 199   11950  55.672156   98823      CNG  110       1.0          0  1600
# 303   11500  39.000000   39524   Petrol   97       NaN          0  1398
#
#       Doors  Weight
# 351       5    1060
# 250       5    1075
# 1267      5    1075
# 838       3    1065
# 1005      5    1070
# 294       5    1080
# 789       5    1070
# 814       3    1050
# 418       3    1115
# 307       3    1040
# 1081      5    1135
# 954       4    1035
# 1415      3    1050
# 1193      3    1055
# 623       3    1065
# 1274      5    1075
# 414       3    1045
# 150       5    1110
# 199       5    1119
# 303       3    1025

# %%
df["FuelType"].value_counts().iloc[0]
# Out:
# 1177

# %%
df['FuelType'] = df['FuelType'].fillna(df['FuelType'].mode()[0])

# %%
df.sample(frac=1).head(20)
# Out:
#       Price        Age      KM FuelType   HP  MetColor  Automatic    CC  \
# 937    8950  68.000000   54875   Petrol  110       1.0          0  1600
# 808    8250  63.000000   72522   Petrol  110       1.0          0  1600
# 634    8950  62.000000  125175   Diesel  116       0.0          0  2000
# 305   11895  41.000000   39439   Petrol   97       0.0          0  1400
# 752    8450  65.000000   80439   Petrol  110       1.0          0  1600
# 158   19750  17.000000   11999   Petrol  110       1.0          0  1600
# 673    9250  67.000000  104000   Petrol   86       0.0          0  1300
# 159   19750  16.000000   11754   Petrol  110       0.0          1  1600
# 1005   9750  55.672156   37759   Petrol  110       1.0          0  1600
# 907    8950  65.000000   58829   Petrol  110       0.0          0  1600
# 311   13995  44.000000   38461   Petrol  110       NaN          0  1600
# 1127   8700  75.000000  109540   Petrol  110       0.0          0  1600
# 782    8950  59.000000   76162   Petrol  110       1.0          0  1600
# 1107   7250  55.672156  121545   Petrol  110       1.0          0  1600
# 17    17950  24.000000   21716   Petrol  110       1.0          0  1600
# 1212   8250  72.000000   86860   Petrol  110       0.0          0  1600
# 1008   9750  62.000000   37000   Petrol   86       0.0          0  1300
# 358   12750  43.000000   24553   Petrol  110       1.0          0  1600
# 306    9950  44.000000   39000   Petrol   97       1.0          0  1400
# 424    9750  52.000000   89000   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# 937       5    1070
# 808       3    1050
# 634       5    1150
# 305       5    1060
# 752       4    1035
# 158       5    1130
# 673       3    1020
# 159       5    1180
# 1005      5    1070
# 907       3    1050
# 311       5    1080
# 1127      5    1085
# 782       5    1075
# 1107      5    1070
# 17        3    1105
# 1212      5    1075
# 1008      3    1015
# 358       5    1080
# 306       3    1025
# 424       5    1075

# %%
df['FuelType'].isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   float64
#  2   KM         1436 non-null   object
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 112.3+ KB

# %%
df['MetColor'] = df['MetColor'].mode()[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   float64
#  2   KM         1436 non-null   object
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1436 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 112.3+ KB

# %% [markdown]
# # Will perform binning on Age

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].min()
# Out:
# 1.0

# %%
df['time_period'] = pd.cut(df['Age'], 5, labels=['New', 'Recent', 'Mid', 'Old', 'Ancient'])

# %%
df[df['Age'] == 1.0]
# Out:
#      Price  Age KM FuelType   HP  MetColor  Automatic    CC  Doors  Weight  \
# 184  17795  1.0  1   Petrol   98       1.0          0  1400      4    1100
# 185  18245  1.0  1   Petrol  110       1.0          0  1600      5    1075
#
#     time_period
# 184         New
# 185         New

# %%
df.sample(frac=1).head(20)
# Out:
#       Price   Age      KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 1283   8950  76.0   73116   Petrol  110       1.0          0  1600      5
# 1043   9450  66.0   15110   Petrol   86       1.0          0  1300      5
# 540   10950  47.0   46391   Petrol  110       1.0          0  1600      5
# 392    9950  49.0  131364   Petrol  110       1.0          0  1600      5
# 1320   9400  69.0   67092   Diesel   72       1.0          0  2000      3
# 350   11895  39.0   27170   Petrol   97       1.0          0  1400      5
# 126   15950  20.0   36000   Petrol  110       1.0          0  1600      5
# 287    9950  37.0   44757   Petrol   97       1.0          0  1400      3
# 1053   5750  76.0  183277   Diesel   72       1.0          0  2000      3
# 698   10250  61.0   95147   Petrol  110       1.0          0  1600      3
# 1417   8750  79.0   39800   Petrol  107       1.0          1  1600      3
# 138   23000  11.0   25000   Diesel  116       1.0          0  2000      5
# 1006  10950  61.0   37500   Petrol  110       1.0          0  1600      5
# 85    17450  28.0    8537   Petrol  110       1.0          0  1600      5
# 1208   7950  70.0   87000   Petrol  110       1.0          0  1600      4
# 621    6900  60.0  139800   Diesel   72       1.0          0  2000      3
# 1300   7950  76.0   71000   Petrol  110       1.0          0  1600      3
# 606    7500  59.0  190900   Diesel   72       1.0          0  2000      3
# 412    8950  48.0   98100   Petrol   69       1.0          0  1900      5
# 1351   5845  70.0   60600   Petrol   86       1.0          0  1300      3
#
#       Weight time_period
# 1283    1075     Ancient
# 1043    1035     Ancient
# 540     1075         Mid
# 392     1075         Old
# 1320    1115     Ancient
# 350     1060         Mid
# 126     1075      Recent
# 287     1025         Mid
# 1053    1115     Ancient
# 698     1050         Old
# 1417    1080     Ancient
# 138     1320         New
# 1006    1085         Old
# 85      1130      Recent
# 1208    1035     Ancient
# 621     1115         Old
# 1300    1050     Ancient
# 606     1115         Old
# 412     1140         Mid
# 1351    1060     Ancient

# %%
df['time_period'].value_counts().plot(kind='bar', xlabel="Period", ylabel="Frequency")
# Out:
# <Axes: xlabel='Period', ylabel='Frequency'>

# %% [markdown]
# # Data Smoothening will be done on Price

# %%
df['Price'].min()
# Out:
# 4350

# %%
df['Price'].max()
# Out:
# 32500

# %% [markdown]
# ## Explanation
# - We are sorting the price before applying the smoothening function (rolling mean) so that the groups that are formed have values that are closer to each other. By doing so, the mean produced and assigned will make more sense.
#
# - Later we are reassigning the smoothened prices with the proper indices

# %%
sorted_prices = df['Price'].sort_values().reset_index()
sorted_prices['Smooth_Price'] = sorted_prices['Price'].rolling(window=10).mean()

# %%
sorted_prices
# Out:
#       index  Price  Smooth_Price
# 0       191   4350           NaN
# 1      1048   4400           NaN
# 2       393   4450           NaN
# 3       192   4750           NaN
# 4       402   5150           NaN
# ...     ...    ...           ...
# 1431    112  24950       23580.0
# 1432    115  24990       23829.0
# 1433    110  31000       24679.0
# 1434    111  31275       25531.5
# 1435    109  32500       26486.5
#
# [1436 rows x 3 columns]

# %%
index_prices = sorted_prices.sort_values(by='index').set_index('index')
index_prices
# Out:
#        Price  Smooth_Price
# index
# 0      13500       13450.0
# 1      13750       13575.0
# 2      13950       13950.0
# 3      14950       14920.0
# 4      13750       13525.0
# ...      ...           ...
# 1431    7500        7474.4
# 1432   10845       10764.5
# 1433    8500        8500.0
# 1434    7250        7250.0
# 1435    6950        6950.0
#
# [1436 rows x 2 columns]

# %%
df['Smooth_Price'] = index_prices['Smooth_Price']

# %%
df.sample(frac=1).head(20)
# Out:
#       Price   Age      KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 1302   7450  77.0   70932   Petrol   110       1.0          0  1600      3
# 1419   8450  75.0   38945   Petrol   110       1.0          0  1600      3
# 690    8750  64.0   98291   Petrol    86       1.0          0  1300      4
# 605    5950  68.0  194545   Petrol    86       1.0          0  1300      4
# 891   11500  68.0   61100   Petrol   110       1.0          0  1600      5
# 836   10950  68.0   67146   Petrol   110       1.0          0  1600      5
# 542   10500  52.0   46029   Petrol   110       1.0          0  1600      4
# 15    22000  28.0   18739   Petrol  ????       1.0          0  1800      3
# 1396   9800  77.0   48838   Petrol   110       1.0          0  1600      3
# Out:
# 15

# %%
df['KM'].dtype
# Out:
# dtype('O')

# %%
df['KM'] = df['KM'].replace('??', np.nan)

# %%
df[df['KM'] == '??'].value_counts().sum()
# Out:
# 0

# %%
df['KM'].isna().sum()
# Out:
# 15

# %%
df['KM'].sample(frac=1).head(20)
# Out:
# 970      47612
# 261      50873
# 1392     49827
# 312      38078
# 563      38403
# 402     113997
# 37       10000
# 292      43000
# 951      52548
# 1084    134539
# 852      65000
# 1269     75000
# 282      45713
# 1188     90370
# 246      55968
# 181        450
# 20       67660
# 1202     88186
# 492      59000
# 376      12000
# Name: KM, dtype: object

# %%
df['KM'] = df['KM'].fillna(0)

# %%
df['KM'].isna().sum()
# Out:
# 0

# %%
df['KM'].dtype
# Out:
# dtype('O')

# %%
df['KM'] = df['KM'].astype(int)

# %%
df['KM'].dtype
# Out:
# dtype('int64')

# %%
df['KM'].sample(frac=1).head(20)
# Out:
# 466      68414
# 867      63328
# 1428         0
# 719      88807
# 106      11500
# 994      43000
# 1285     72703
# 465      68520
# 485      62280
# 272      48052
# 387     142130
# 624     135337
# 565      37000
# 340      29716
# 1074    146304
# 1145    101855
# 176       7000
# 472      65170
# 710      91505
# 1175     94079
# Name: KM, dtype: int64

# %%
round(df['KM'].mean())
# Out:
# 67930

# %%
df['KM'] = df['KM'].replace(0, round(df['KM'].mean()))

# %%
df['FuelType'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG'], dtype=object)

# %%
df_encoded = pd.get_dummies(df, columns=['FuelType'])
df_encoded
# Out:
#       Price        Age     KM   HP  MetColor  Automatic    CC  Doors  Weight  \
# 0     13500  23.000000  46986   90       1.0          0  2000      3    1165
# 1     13750  23.000000  72937   90       1.0          0  2000      3    1165
# 2     13950  24.000000  41711   90       1.0          0  2000      3    1165
# 3     14950  26.000000  48000   90       1.0          0  2000      3    1165
# 4     13750  30.000000  38500   90       1.0          0  2000      3    1170
# ...     ...        ...    ...  ...       ...        ...   ...    ...     ...
# 1431   7500  55.672156  20544   86       1.0          0  1300      3    1025
# 1432  10845  72.000000  67930   86       1.0          0  1300      3    1015
# 1433   8500  55.672156  17016   86       1.0          0  1300      3    1015
# 1434   7250  70.000000  67930   86       1.0          0  1300      3    1015
# 1435   6950  76.000000      1  110       1.0          0  1600      5    1114
#
#      time_period  Smooth_Price  FuelType_CNG  FuelType_Diesel  FuelType_Petrol
# 0         Recent       13450.0         False             True            False
# 1         Recent       13575.0         False             True            False
# 2         Recent       13950.0         False             True            False
# 3         Recent       14920.0         False             True            False
# 4         Recent       13525.0         False             True            False
# ...          ...           ...           ...              ...              ...
# 1431         Old        7474.4         False            False             True
# 1432     Ancient       10764.5         False            False             True
# 1433         Old        8500.0         False            False             True
# 1434     Ancient        7250.0         False            False             True
# 1435     Ancient        6950.0         False            False             True
#
# [1436 rows x 14 columns]

# %%
df['Fuel_Ordinal'] = OrdinalEncoder(categories=[['Petrol', 'Diesel', 'CNG']]).fit_transform(df[['FuelType']])
df
# Out:
#       Price        Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23